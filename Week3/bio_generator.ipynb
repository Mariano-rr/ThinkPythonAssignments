# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariano-rr/ThinkPythonAssignments/blob/main/Week3/bio_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATEMENTS
#(NONE)

#FUNCTION DEFINITIONS
#(NONE)

#PROGRAM LOGIC
#Assign values to the variables: name, birth_year, current_year, and goal.
name = "Mariano Ramirez-Rodriguez"
goal = "become an electrical engineer."
birth_year = 2008
current_year = 2026

#Calculate age
age = current_year - birth_year

#Print top border
print( "=" * 25 )

#Print bio sentence
print( "My name is " + name + " and I am " + str(age) + " years old." + " My goal is to " + goal )

#Print bottom border
print( "=" * 25 )
# Out:
# =========================
# My name is Mariano Ramirez-Rodriguez and I am 18 years old. My goal is to become an electrical engineer.
# =========================
