# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariano-rr/ThinkPythonAssignments/blob/main/Week4/print_bio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATEMENTS
#(NONE)

#FUNCTION DEFINTIONS
#Define print_bio with 3 parameters (name, age, goal).
def print_bio(name, age, goal):

#Inside the function, use string multiplication for a border line.
  print( '*' * 25)

#Print the bio details using the parameter names.
  print( 'Name: ' + name + ', Age: ' + str(age) + ', Goal: ' + goal + '.')
  print( '*' * 25)
  print()

#PROGRAM LOGIC
#Call print_bio using my own info.
print_bio( 'Mariano', 18, 'Pass this class' )

#Call print_bio using info of Terry Crews.
print_bio( 'Terry Crews', 57, 'Pursue a career in entertainment' )

#Call print_bio using info of Walter White.
print_bio( 'Walter White', 52, 'Secure the financial future of his family' )
# Out:
# *************************
# Name: Mariano, Age: 18, Goal: Pass this class.
# *************************
#
# *************************
# Name: Terry Crews, Age: 57, Goal: Pursue a career in entertainment.
# *************************
#
# *************************
# Name: Walter White, Age: 52, Goal: Secure the financial future of his family.
# *************************
