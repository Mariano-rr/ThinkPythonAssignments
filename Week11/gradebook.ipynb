# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariano-rr/ThinkPythonAssignments/blob/main/Week11/gradebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
#(NONE)

# FUNCTION DEFINITIONS
#Create a functionc called add_players with a parameter: dictionary
def add_players(dictionary):
# A while loop will be present and will ask for user input for a name
  while True:
    Name = input( 'Enter a name: (or done) ' )
#   If the name is "done" the function is ended with a blank return statement
    if Name == 'done':
#     If done is typed in an empty dictionary, the function will return an error message
      if len(dictionary) == 0:
        print( 'Cannot have an empty dictionary' )
      else:
        return
#   After the name is entered, it will ask you to enter a grade associated with that name
    else:
      Grade = int(input( 'Enter a grade: (0-100) ' ))
#     The function will then edit the dictionary to contain the name as a key and grade as a value
      dictionary[Name] = Grade

#Create a function called calculate_average with a parameter: dictionary
#The function will have a total grade variable with a value of 0 that will be modified
#A for loop will run through the values of the dictionary and add them up in the total grade variable
#The function will then take the length of the dictionary and store it in the divider variable
#then it will take the total grade and divide it by the divider variable and return the value

# PROGRAM LOGIC
#Create an empty dictionary called gradebook
gradebook = {}

#Call the add_players function with gradebook entered as the parameter
add_players(gradebook)

#print the an empty space and then Class Report
#Create a for loop to loop through gradebook and print out the key and values
#print class average followed by the returned value of the calculate_average

print(gradebook)
# Out:
# Enter a name: (or done) Alice
# Enter a grade: (0-100) 95
# Enter a name: (or done) Bob
# Enter a grade: (0-100) 82
# Enter a name: (or done) done
# {'Alice': 95, 'Bob': 82}
