# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariano-rr/ThinkPythonAssignments/blob/main/Week7/Modular_ATM_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
#    - Return True
def verify_pin():
  while True:
    pin = int(input( 'Enter PIN: ' ))
    if pin == 1234:
      print( 'PIN Verified.' )
      return True
    print( 'Incorrect PIN. Try Again.' )

# 2. Define withdraw(balance, amount):
#    - Check if enough money exists
#    - Return the new (or old) balance
def withdraw(balance, amount):
  if amount > balance:
    print( 'Insufficient funds')
    return balance
  else:
    print( 'Withdrawl successful.' )
    balance = balance - amount
    return balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
current_balance = 500

# 2. Call verify_pin()
verify_pin()

# 3. Get withdrawal amount from user input
amount = float(input( 'Enter withdrawal amount: '))

# 4. Update current_balance by calling withdraw()
current_balance = withdraw(current_balance, amount)

# 5. Print the final balance
print('Current Balance: $' + str(current_balance))
# Out:
# Enter PIN: 0000
# Incorrect PIN. Try Again.
# Enter PIN: 1234
# PIN Verified.
# Enter withdrawal amount: 150
# Withdrawl successful.
# Current Balance: $350.0
