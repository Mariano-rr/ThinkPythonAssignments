# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariano-rr/ThinkPythonAssignments/blob/main/Week5/Cinema_Pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
def calculate_ticket(age, hour):

# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
  if age <= 12 or age >= 65:
    price = 8
  else:
    price = 12

# 3. Logic: If hour < 17, subtract 2 from the price.
  if hour < 17:
    final_price = price - 2
  else:
    final_price = price
# 4. Print the final price.
  print( 'Your ticket price is: $' + str(final_price) + '.00' )
  1
# PROGRAM LOGIC
# 1. input() for age (int)
age = int(input( 'Enter age: '))
# 2. input() for movie hour (int)
hour = int(input( 'Enter movie hour (0-23): '))
# 3. Call calculate_ticket()
calculate_ticket(age, hour)
# Out:
# Enter age: 70
# Enter movie hour (0-23): 14
# Your ticket price is: $6.00
