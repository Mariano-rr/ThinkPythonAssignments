# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariano-rr/ThinkPythonAssignments/blob/main/Week2/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATEMENTS
#(NONE)

#FUNCTION DEFINITIONS
#(NONE)

#PROGRAM LOGIC
#print the total minutes in a movie ( 60 * 2 + 45 ).
print( "Total minutes in movie: " + str(60 * 2 + 45))

#print the years since 1947 ( 2026 - 1947 ).
print( "Years since first bug: " + str(2026 - 1947))

#print the total costs of 7 books ( 7 * 35 ).
print( "Total cost of books: " + str(7 * 35))
# Out:
# Total minutes in movie: 165
# Years since first bug: 79
# Total cost of books: 245
