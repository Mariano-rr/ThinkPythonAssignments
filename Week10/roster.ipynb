# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariano-rr/ThinkPythonAssignments/blob/main/Week10/roster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
#(NONE)

# FUNCTION DEFINITIONS
#Create a function called add_players with a paramater: List
def add_players(List):
# The function will have a while loop inside that will keep going and asking for user input to edit the list
  while True:
    word_entered = input( 'Enter player name (or quit to stop): ')
#   If the word quit is typed in, the loop breaks, if not it will continue to add to the list.
    if word_entered == 'quit':
      return
    else:
      List.append(word_entered)

#Create a function called is_on_roster with 2 parameters: List, Name
def is_on_roster(List, Name):
# The function will take the user input for name and search for it inside the list
  if Name in List:
#   Will return true if the name is found in list and false if not.
    return True
  return False

# PROGRAM LOGIC
#Create an empty list named roster
roster = []

#Call the add_players function
add_players(roster)
print()

#Ask for user to enter a name of what they want to find in the list
Name = input( 'Enter a player name: ')

#Create an if statement that checks the returned value of the is_on_roster function
if is_on_roster(roster, Name):

#If it returns true, print( 'Result: Player found!' )
  print( 'Result: Player found!' )

#If it returns false, print( 'Result: Player not found.' )
else:
  print( 'Result: Player not found.' )
# Out:
# Enter player name (or quit to stop): Jordan
# Enter player name (or quit to stop): Pippen
# Enter player name (or quit to stop): quit
#
# Enter a player name: Jordan
# Result: Player found!
